# %% [markdown]
# # Worldwide Earthquake Events API - Silver Layer Processing

# %%
from pyspark.sql.functions import col
from pyspark.sql.types import TimestampType
from datetime import date, timedelta
# Out:
# StatementMeta(, f42697b8-c99d-4363-a99d-7ef7c557033a, 4, Finished, Available, Finished)

# %%
df = spark.read.option("multiline", "true").json(f"Files/{start_date}_earthquake_data.json")
display(df.limit(5))
# Out:
# StatementMeta(, f42697b8-c99d-4363-a99d-7ef7c557033a, 7, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, b968c14d-1639-4426-9ca0-382c14e2a21f)

# %%
df = df.select(
        'id',
        col('geometry.coordinates').getItem(0).alias('longitude'),
        col('geometry.coordinates').getItem(1).alias('latitude'),
        col('geometry.coordinates').getItem(2).alias('elevation'),
        col('properties.title').alias('title'),
        col('properties.place').alias('place_description'),
        col('properties.sig').alias('sig'),
        col('properties.mag').alias('mag'),
        col('properties.magType').alias('magType'),
        col('properties.time').alias('time'),
        col('properties.updated').alias('updated')
        )
# Out:
# StatementMeta(, f42697b8-c99d-4363-a99d-7ef7c557033a, 8, Finished, Available, Finished)

# %%
display(df.limit(5))
# Out:
# StatementMeta(, f42697b8-c99d-4363-a99d-7ef7c557033a, 9, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 3babb5c5-7078-4c80-9b4c-79e270947377)

# %%
# Convert from milliseconds to timestamp format.
df = df.withColumn('time', col('time')/1000).\
    withColumn('updated', col('updated')/1000).\
    withColumn('time', col('time').cast(TimestampType())).\
    withColumn('updated', col('updated').cast(TimestampType()))
# Out:
# StatementMeta(, f42697b8-c99d-4363-a99d-7ef7c557033a, 10, Finished, Available, Finished)

# %%
display(df.limit(5))
# Out:
# StatementMeta(, f42697b8-c99d-4363-a99d-7ef7c557033a, 11, Finished, Available, Finished)
# SynapseWidget(Synapse.DataFrame, 4954a58f-c866-4e02-940f-4ae8afd94dd7)

# %%
df.write.mode('append').saveAsTable('earthquake_events_silver')
# Out:
# StatementMeta(, f42697b8-c99d-4363-a99d-7ef7c557033a, 12, Finished, Available, Finished)
